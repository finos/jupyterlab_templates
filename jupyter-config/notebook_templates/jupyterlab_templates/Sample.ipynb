# %% [markdown]
# # Sample Template

# %% [markdown]
# Here is some sample text, and a first block of code

# %%
# insert code here

# %% [markdown]
# ## A second heading

# %% [markdown]
# and some more text
